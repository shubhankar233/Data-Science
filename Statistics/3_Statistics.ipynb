# %%
from scipy import stats

# %%
stats.norm.cdf(70,60,10)
# Out:
# np.float64(0.8413447460685429)

# %%
stats.norm.cdf(680,711,29)
# Out:
# np.float64(0.14254260383881612)

# %%
1-stats.norm.cdf(720,711,29)
# Out:
# np.float64(0.37814937265194704)

# %%
stats.norm.cdf(740,711,29)-stats.norm.cdf(680,711,29)                   ## Probablity between 680 and 740 P(X: 680-740)
# Out:
# np.float64(0.6988021422297268)

# %%
cp "/content/drive/MyDrive/Colab Notebooks/3_Statistics.ipynb" "/content/Data-Science/Python/"

# %%
# !cd /content/Data-Science/Statistics
# Out:
# /bin/bash: line 1: cd: /content/Data-Science/Statistics: No such file or directory

# %%
# !mkdir /content/Da
