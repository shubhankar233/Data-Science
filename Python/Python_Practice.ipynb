# %%
# !git clone https://github.com/shubhankar233/Data-Science.git
# Out:
# Cloning into 'Data-Science'...
# ...

# %%
# !ls
# Out:
# Data-Science  sample_data

# %%
# !pwd
# Out:
# /content

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import os
print(os.path.abspath("Python_Practice.ipynb"))
# Out:
# /content/Python_Practice.ipynb

# %%
# !mkdir /content/Data-Science/Python

# %%
# !mv /content/Python_Practice.ipynb /content/Data-Science/Python/
# Out:
# mv: cannot stat '/content/Python_Practice.ipynb': No such file or directory

# %%
# !mv "/content/Python_Practice.ipynb" /content/Data-Science/Python/
# Out:
# mv: cannot stat '/content/Python_Practice.ipynb': No such file or directory

# %%
# !ls /content
# Out:
# sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# 'Copy of Python_Practice.ipynb'   Python_Practice.ipynb

# %%
# !git clone https://github.com/shubhankar233/Data-Science.git
